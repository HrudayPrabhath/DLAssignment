# %% [markdown]
# <a href="https://colab.research.google.com/github/HrudayPrabhath/DLAssignment/blob/main/DL_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GRU

# %%
import numpy as np
from tensorflow.keras.datasets import imdb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding,GRU,Dense
from tensorflow.keras.preprocessing import sequence

# %%
max_words = 5000
(xt,yt),(xte,yte)= imdb.load_data(num_words=max_words)

max_len =500
xt=sequence.pad_sequences(xt,maxlen=max_len)
xte=sequence.pad_sequences(xte,maxlen=max_len)

model=Sequential()
model.add(Embedding(max_words,100,input_length=max_len))
model.add(GRU(128))
model.add(Dense(1,activation='sigmoid'))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 0s 0us/step

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
batch_size=128
epochs=5
model.fit(xt,yt,batch_size=batch_size,epochs=epochs)
# Out:
# Epoch 1/5
# 196/196 [==============================] - 51s 220ms/step - loss: 0.4603 - accuracy: 0.7694
# Epoch 2/5
# 196/196 [==============================] - 27s 136ms/step - loss: 0.2791 - accuracy: 0.8886
# Epoch 3/5
# 196/196 [==============================] - 14s 70ms/step - loss: 0.2417 - accuracy: 0.9080
# Epoch 4/5
# 196/196 [==============================] - 12s 61ms/step - loss: 0.1934 - accuracy: 0.9282
# Epoch 5/5
# 196/196 [==============================] - 11s 55ms/step - loss: 0.1566 - accuracy: 0.9433

# %%
loss,accuracy=model.evaluate(xte,yte,batch_size=batch_size)
print("accuracy:",accuracy)
print("loss:",loss)
# Out:
# 196/196 [==============================] - 3s 12ms/step - loss: 0.3811 - accuracy: 0.8746
# accuracy: 0.8745599985122681
# loss: 0.3811190724372864

# %%
history=model.fit(xt,yt,batch_size=batch_size,epochs=epochs)
# Out:
# Epoch 1/5
# 196/196 [==============================] - 10s 54ms/step - loss: 0.1370 - accuracy: 0.9518
# Epoch 2/5
# 196/196 [==============================] - 10s 51ms/step - loss: 0.1071 - accuracy: 0.9624
# Epoch 3/5
# 196/196 [==============================] - 7s 37ms/step - loss: 0.0838 - accuracy: 0.9714
# Epoch 4/5
# 196/196 [==============================] - 8s 38ms/step - loss: 0.0709 - accuracy: 0.9760
# Epoch 5/5
# 196/196 [==============================] - 7s 34ms/step - loss: 0.0543 - accuracy: 0.9819

# %%
train_loss1 = history.history['loss']
train_acc1 = history.history['accuracy']
xc1=range(len(train_acc1))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc1, train_acc1)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend('train')

# %% [markdown]
# # LSTM

# %%
from tensorflow.keras.layers import Embedding,LSTM,Dense

# %%
model = Sequential()
model.add(Embedding(max_words,100, input_length=max_len))
model.add(LSTM(128))
model.add(Dense(units=1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
epochs = 5
batch_size = 128

hist=model.fit(xt, yt, epochs=epochs, batch_size=batch_size)
# Out:
# Epoch 1/5
# 196/196 [==============================] - 36s 171ms/step - loss: 0.4641 - accuracy: 0.7750
# Epoch 2/5
# 196/196 [==============================] - 17s 88ms/step - loss: 0.2754 - accuracy: 0.8907
# Epoch 3/5
# 196/196 [==============================] - 13s 68ms/step - loss: 0.2327 - accuracy: 0.9103
# Epoch 4/5
# 196/196 [==============================] - 13s 64ms/step - loss: 0.1979 - accuracy: 0.9256
# Epoch 5/5
# 196/196 [==============================] - 9s 47ms/step - loss: 0.2170 - accuracy: 0.9145

# %%
loss,accuracy=model.evaluate(xte,yte,batch_size=batch_size)
print("accuracy:",accuracy)
print("loss:",loss)
# Out:
# 196/196 [==============================] - 3s 14ms/step - loss: 0.3324 - accuracy: 0.8740
# accuracy: 0.873960018157959
# loss: 0.3323705196380615

# %%
train_loss2 = hist.history['loss']
train_acc2 = hist.history['accuracy']
xc2=range(len(train_acc2))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc2, train_acc2)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend('train')

# %% [markdown]
# # RNN

# %%
from tensorflow.keras.layers import Embedding,RNN
from keras import layers

# %%
model = Sequential()
model.add(Embedding(max_words,100, input_length=max_len))
model.add(layers.LSTM(128))
model.add(layers.Dense(10))
model.add(Dense(units=1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
epochs = 5
batch_size = 128

h=model.fit(xt, yt, epochs=epochs, batch_size=batch_size, validation_split=0.2)
# Out:
# Epoch 1/5
# 157/157 [==============================] - 30s 173ms/step - loss: 0.5987 - accuracy: 0.6850 - val_loss: 0.3985 - val_accuracy: 0.8200
# Epoch 2/5
# 157/157 [==============================] - 20s 125ms/step - loss: 0.3082 - accuracy: 0.8742 - val_loss: 0.2906 - val_accuracy: 0.8806
# Epoch 3/5
# 157/157 [==============================] - 13s 85ms/step - loss: 0.2335 - accuracy: 0.9112 - val_loss: 0.3432 - val_accuracy: 0.8680
# Epoch 4/5
# 157/157 [==============================] - 11s 68ms/step - loss: 0.2068 - accuracy: 0.9208 - val_loss: 0.3408 - val_accuracy: 0.8658
# Epoch 5/5
# 157/157 [==============================] - 9s 55ms/step - loss: 0.1637 - accuracy: 0.9382 - val_loss: 0.3338 - val_accuracy: 0.8678

# %%
loss,accuracy=model.evaluate(xte,yte,batch_size=batch_size)
print("accuracy:",accuracy)
print("loss:",loss)
# Out:
# 196/196 [==============================] - 3s 13ms/step - loss: 0.3411 - accuracy: 0.8686
# accuracy: 0.8686000108718872
# loss: 0.341059148311615

# %%
train_loss3 = h.history['loss']
train_acc3 = h.history['accuracy']
xc3=range(len(train_loss3))
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(xc3, train_acc3)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend('train')

# %% [markdown]
# # PLOT

# %%
plt.plot(xc1, train_acc1)
plt.plot(xc2, train_acc2)
plt.plot(xc3, train_acc3)
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend(["GRU","LSTM","RNN"])
